# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
import matplotlib as mpl
import textwrap

# %%
rcParams['font.family'] = 'Proxima Nova'
text_color = '#323232'
mpl.rcParams['text.color'] = text_color
mpl.rcParams['axes.labelcolor'] = text_color
mpl.rcParams['xtick.color'] = text_color
mpl.rcParams['ytick.color'] = 'white'

colors = {
    'orange':'#f4731f',
    'turquoise': '#41B6E6',
    'purple': '#512D6D',
    'blue': '#006298',
    'l_blue': '#99D6EA',
    'd_blue': '#01426A',
    'green': '#78BE20'
}

# %%
data = pd.read_csv('../data/any_q1_df.csv')

# %%
data
# Out:
#                 group      subgroup  prop
# 0             age_cat         18-24    21
# 1             age_cat         25-34    36
# 2             age_cat         35-44    42
# 3             age_cat         45-54    26
# 4             age_cat         55-64     8
# 5             age_cat           65+     4
# 6    residential_area         Urban    34
# 7    residential_area      Suburban    16
# 8    residential_area         Rural    15
# 9   employment_status      Employed    33
# 10  employment_status  Not employed     9
# 11          child_age   12 or under    50
# 12          child_age   13 or older    22
# 13          child_age   No children    12
# 14          race_ethn         White    17
# 15          race_ethn      Hispanic    37
# 16          race_ethn         Black    29

# %%
data.iloc[11]['prop']
# Out:
# 50

# %%
fig, ax = plt.subplots(nrows = 22, figsize=(7.5,10), sharex = True)
fontsize_yticks = 12
fontsize_title = 20
fontsize_datalabs = 12
fontsize_caption = 8

title = "Proportion saying they have experienced at least\none caregiving challenge recently"
fig.suptitle(title.upper(), 
             x = 0.5, y = 1,
             ha='center', va='top', 
             fontsize=fontsize_title, fontproperties = 'DIN Condensed')

ax[0].set_xticks([])
ax[0].set_yticks([0])
ax[0].set_yticklabels(labels = ['Age of children'.upper()], 
                      fontsize = fontsize_yticks+4, weight = 'bold', color = text_color)
ax[0].barh(0, 0)

ax[1].barh(data.iloc[11]['subgroup'], data.iloc[11]['prop'], color = colors['blue'])
ax[1].set_yticks([0])
ax[1].set_yticklabels(labels=["Parent of child age 12 or under"], 
                      fontsize=fontsize_yticks, color = text_color)
ax[1].annotate(f"{data.iloc[11]['prop']}%",
               (data.iloc[11]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[2].barh(data.iloc[12]['subgroup'], data.iloc[12]['prop'], color = colors['blue'], alpha = 0.8)
ax[2].set_yticks([0])
ax[2].set_yticklabels(labels=["Parent of child age 13 or older"], 
                      fontsize=fontsize_yticks, color = text_color)
ax[2].annotate(f"{data.iloc[12]['prop']}%",
               (data.iloc[12]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[3].barh(data.iloc[13]['subgroup'], data.iloc[13]['prop'], color = colors['blue'], alpha = 0.6)
ax[3].set_yticks([0])
ax[3].set_yticklabels(labels=["No children"], 
                      fontsize=fontsize_yticks, color = text_color)
ax[3].annotate(f"{data.iloc[13]['prop']}%",
               (data.iloc[13]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[4].set_xticks([])
ax[4].set_yticks([0])
ax[4].set_yticklabels(labels = ['Age'.upper()], 
                      fontsize = fontsize_yticks+4, weight = 'bold', color = text_color)
ax[4].barh(0, 0)

ax[5].barh(data.iloc[0]['subgroup'], data.iloc[0]['prop'], color = colors['purple'])
ax[5].set_yticks([0])
ax[5].set_yticklabels(labels=[data.iloc[0]['subgroup']], 
                      fontsize=fontsize_yticks, color = text_color)
ax[5].annotate(f"{data.iloc[0]['prop']}%",
               (data.iloc[0]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[6].barh(data.iloc[1]['subgroup'], data.iloc[1]['prop'], color = colors['purple'], alpha = 0.9)
ax[6].set_yticks([0])
ax[6].set_yticklabels(labels=[data.iloc[1]['subgroup']], 
                      fontsize=fontsize_yticks, color = text_color)
ax[6].annotate(f"{data.iloc[1]['prop']}%",
               (data.iloc[1]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[7].barh(data.iloc[2]['subgroup'], data.iloc[2]['prop'], color = colors['purple'], alpha = 0.8)
ax[7].set_yticks([0])
ax[7].set_yticklabels(labels=[data.iloc[2]['subgroup']], 
                      fontsize=fontsize_yticks, color = text_color)
ax[7].annotate(f"{data.iloc[2]['prop']}%",
               (data.iloc[2]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[8].barh(data.iloc[3]['subgroup'], data.iloc[3]['prop'], color = colors['purple'], alpha = 0.7)
ax[8].set_yticks([0])
ax[8].set_yticklabels(labels=[data.iloc[3]['subgroup']], 
                      fontsize=fontsize_yticks, color = text_color)
ax[8].annotate(f"{data.iloc[3]['prop']}%",
               (data.iloc[3]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[9].barh(data.iloc[4]['subgroup'], data.iloc[4]['prop'], color = colors['purple'], alpha = 0.6)
ax[9].set_yticks([0])
ax[9].set_yticklabels(labels=[data.iloc[4]['subgroup']], 
                      fontsize=fontsize_yticks, color = text_color)
ax[9].annotate(f"{data.iloc[4]['prop']}%",
               (data.iloc[4]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[10].barh(data.iloc[5]['subgroup'], data.iloc[5]['prop'], color = colors['purple'], alpha = 0.5)
ax[10].set_yticks([0])
ax[10].set_yticklabels(labels=[data.iloc[5]['subgroup']], 
                       fontsize=fontsize_yticks, color = text_color)
ax[10].annotate(f"{data.iloc[5]['prop']}%",
               (data.iloc[5]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[11].set_xticks([])
ax[11].set_yticks([0])
ax[11].set_yticklabels(labels = ['Employment status'.upper()], 
                       fontsize = fontsize_yticks+4, weight = 'bold', color = text_color)
ax[11].barh(0, 0)

ax[12].barh(data.iloc[9]['subgroup'], data.iloc[9]['prop'], color = colors['l_blue'])
ax[12].set_yticks([0])
ax[12].set_yticklabels(labels=[data.iloc[9]['subgroup']], 
                       fontsize=fontsize_yticks, color = text_color)
ax[12].annotate(f"{data.iloc[9]['prop']}%",
               (data.iloc[9]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[13].barh(data.iloc[10]['subgroup'], data.iloc[10]['prop'], color = colors['l_blue'], alpha = 0.5)
ax[13].set_yticks([0])
ax[13].set_yticklabels(labels=[data.iloc[10]['subgroup']], 
                       fontsize=fontsize_yticks, color = text_color)
ax[13].annotate(f"{data.iloc[10]['prop']}%",
               (data.iloc[10]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[14].set_xticks([])
ax[14].set_yticks([0])
ax[14].set_yticklabels(labels = ['Residential area'.upper()], 
                       fontsize = fontsize_yticks+4, weight = 'bold', color = text_color)
ax[14].barh(0, 0)

ax[15].barh(data.iloc[6]['subgroup'], data.iloc[6]['prop'], color = colors['green'])
ax[15].set_yticks([0])
ax[15].set_yticklabels(labels=[data.iloc[6]['subgroup']], 
                       fontsize=fontsize_yticks, color = text_color)
ax[15].annotate(f"{data.iloc[6]['prop']}%",
               (data.iloc[6]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[16].barh(data.iloc[7]['subgroup'], data.iloc[7]['prop'], color = colors['green'], alpha = 0.6)
ax[16].set_yticks([0])
ax[16].set_yticklabels(labels=[data.iloc[7]['subgroup']], 
                       fontsize=fontsize_yticks, color = text_color)
ax[16].annotate(f"{data.iloc[7]['prop']}%",
               (data.iloc[7]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[17].barh(data.iloc[8]['subgroup'], data.iloc[8]['prop'], color = colors['green'], alpha = 0.3)
ax[17].set_yticks([0])
ax[17].set_yticklabels(labels=[data.iloc[8]['subgroup']], 
                       fontsize=fontsize_yticks, color = text_color)
ax[17].annotate(f"{data.iloc[8]['prop']}%",
               (data.iloc[8]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[18].set_xticks([])
ax[18].set_yticks([0])
ax[18].set_yticklabels(labels = ['Race/Ethnicity'.upper()], 
                       fontsize = fontsize_yticks+4, weight = 'bold', color = text_color)
ax[18].barh(0, 0)

ax[19].barh(data.iloc[15]['subgroup'], data.iloc[15]['prop'], color = colors['orange'])
ax[19].set_yticks([0])
ax[19].set_yticklabels(labels=[data.iloc[15]['subgroup']], 
                       fontsize=fontsize_yticks, color = text_color)
ax[19].annotate(f"{data.iloc[15]['prop']}%",
               (data.iloc[15]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[20].barh(data.iloc[16]['subgroup'], data.iloc[16]['prop'], color = colors['orange'], alpha = 0.8)
ax[20].set_yticks([0])
ax[20].set_yticklabels(labels=[data.iloc[16]['subgroup']], 
                       fontsize=fontsize_yticks, color = text_color)
ax[20].annotate(f"{data.iloc[16]['prop']}%",
               (data.iloc[16]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

ax[21].barh(data.iloc[14]['subgroup'], data.iloc[14]['prop'], color = colors['orange'], alpha = 0.6)
ax[21].set_yticks([0])
ax[21].set_yticklabels(labels=[data.iloc[14]['subgroup']], 
                       fontsize=fontsize_yticks, color = text_color)
ax[21].annotate(f"{data.iloc[14]['prop']}%",
               (data.iloc[14]['prop']+2, 0),
               ha = 'center', va = 'center', 
               fontsize = fontsize_datalabs,
               color = text_color,
               weight = 'bold')

sns.despine(bottom=True)#, left = True)
fig.tight_layout(rect = [0,0.05,1,1], h_pad=0)

# create caption
captext = '''Source: JUST Capital/Harris Omnibus Poll Q1. Sample: 2,052 US adults. Dates: August 9-11, 2021. 
Proportion of survey respondents that have personally experienced at least one caregiving challenge recently.
See topline questionnaire in appendix for question wording.'''
fig.text(x = 0, y = 0, 
         ha = 'left', va = 'bottom',
         s = captext, fontdict={'family':'Proxima Nova Condensed', 
                                'fontsize':fontsize_caption})

# insert logo image
logo = plt.imread('../assets/Just Capital_Logo_RGB_500px_SSf.png')
newax = fig.add_axes([0.85,0,0.1,0.1], anchor='SE', zorder=1)
newax.imshow(logo)
newax.axis('off')

# save image file
#plt.show();
fig.savefig('../images/fig02.png', transparent = True, dpi=300, bbox_inches='tight');
